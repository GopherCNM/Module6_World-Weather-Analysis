# %%
# Import the dependencies.
import pandas as pd
import numpy as np
import requests
import sys
sys.path.append('../')

from config import weather_api_key
import time
from citipy import citipy

# %% [markdown]
# # Deliverable 1: Retrieve Weather Data

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 721

# %%
# Establish base URL, create an empty list to hold the weather data.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | upernavik
# Processing Record 2 of Set 1 | buraydah
# Processing Record 3 of Set 1 | arraial do cabo
# Processing Record 4 of Set 1 | salalah
# Processing Record 5 of Set 1 | itarema
# Processing Record 6 of Set 1 | nogent-le-rotrou
# Processing Record 7 of Set 1 | ribeira grande
# Processing Record 8 of Set 1 | tuktoyaktuk
# Processing Record 9 of Set 1 | nicoya
# Processing Record 10 of Set 1 | butaritari
# Processing Record 11 of Set 1 | chukhloma
# Processing Record 12 of Set 1 | cape town
# Processing Record 13 of Set 1 | la romana
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | vanimo
# Processing Record 16 of Set 1 | luderitz
# Processing Record 17 of Set 1 | nang rong
# Processing Record 18 of Set 1 | torbay
# Processing Record 19 of Set 1 | pangoa
# Processing Record 20 of Set 1 | nikolskoye
# Processing Record 21 of Set 1 | dingle
# Processing Record 22 of Set 1 | takaka
# Processing Record 23 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | jamestown
# Processing Record 26 of Set 1 | port elizabeth
# Processing Record 27 of Set 1 | wick
# Processing Record 28 of Set 1 | cidreira
# Processing Record 29 of Set 1 | new norfolk
# Processing Record 30 of Set 1 | hilo
# Processing Record 31 of Set 1 | aklavik
# Processing Record 32 of Set 1 | tessalit
# Processing Record 33 of Set 1 | sao filipe
# Processing Record 34 of Set 1 | saskylakh
# Processing Record 35 of Set 1 | vaini
# Processing Record 36 of Set 1 | provideniya
# Processing Record 37 of Set 1 | ilulissat
# Processing Record 38 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 1 | atar
# Processing Record 40 of Set 1 | lebu
# Processing Record 41 of Set 1 | hermanus
# Processing Record 42 of Set 1 | seymchan
# Processing Record 43 of Set 1 | oriximina
# Processing Record 44 of Set 1 | nueva loja
# Processing Record 45 of Set 1 | la paz
# Processing Record 46 of Set 1 | nanortalik
# Processing Record 47 of Set 1 | severo-kurilsk
# Processing Record 48 of Set 1 | constitucion
# Processing Record 49 of Set 1 | pevek
# Processing Record 50 of Set 1 | matucana
# Processing Record 1 of Set 2 | hermon
# Processing Record 2 of Set 2 | yellowknife
# Processing Record 3 of Set 2 | tiksi
# Processing Record 4 of Set 2 | east london
# Processing Record 5 of Set 2 | mataura
# Processing Record 6 of Set 2 | iquique
# Processing Record 7 of Set 2 | grindavik
# Processing Record 8 of Set 2 | avarua
# Processing Record 9 of Set 2 | tasiilaq
# Processing Record 10 of Set 2 | lawton
# Processing Record 11 of Set 2 | thilogne
# City not found. Skipping...
# Processing Record 12 of Set 2 | olafsvik
# Processing Record 13 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 2 | quesnel
# Processing Record 15 of Set 2 | marsh harbour
# Processing Record 16 of Set 2 | gamba
# Processing Record 17 of Set 2 | busselton
# Processing Record 18 of Set 2 | camacha
# Processing Record 19 of Set 2 | hearst
# Processing Record 20 of Set 2 | ponta do sol
# Processing Record 21 of Set 2 | dunedin
# Processing Record 22 of Set 2 | beyneu
# Processing Record 23 of Set 2 | porto velho
# Processing Record 24 of Set 2 | varnamo
# Processing Record 25 of Set 2 | puerto ayora
# Processing Record 26 of Set 2 | saint-philippe
# Processing Record 27 of Set 2 | geraldton
# Processing Record 28 of Set 2 | cabo san lucas
# Processing Record 29 of Set 2 | punta arenas
# Processing Record 30 of Set 2 | waipawa
# Processing Record 31 of Set 2 | meulaboh
# Processing Record 32 of Set 2 | lugo
# Processing Record 33 of Set 2 | tuatapere
# Processing Record 34 of Set 2 | chitungwiza
# Processing Record 35 of Set 2 | vila velha
# Processing Record 36 of Set 2 | faya
# Processing Record 37 of Set 2 | zhireken
# Processing Record 38 of Set 2 | novo aripuana
# Processing Record 39 of Set 2 | znamenskoye
# Processing Record 40 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 2 | la ronge
# Processing Record 42 of Set 2 | guerrero negro
# Processing Record 43 of Set 2 | northam
# Processing Record 44 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 45 of Set 2 | taikang
# Processing Record 46 of Set 2 | sinkat
# City not found. Skipping...
# Processing Record 47 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 2 | hithadhoo
# Processing Record 49 of Set 2 | kununurra
# Processing Record 50 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 3 | college
# Processing Record 2 of Set 3 | umtata
# Processing Record 3 of Set 3 | carnarvon
# Processing Record 4 of Set 3 | katsuura
# Processing Record 5 of Set 3 | bredasdorp
# Processing Record 6 of Set 3 | mayor pablo lagerenza
# Processing Record 7 of Set 3 | nizwa
# Processing Record 8 of Set 3 | khatanga
# Processing Record 9 of Set 3 | paamiut
# Processing Record 10 of Set 3 | diamantino
# Processing Record 11 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 3 | malwan
# City not found. Skipping...
# Processing Record 13 of Set 3 | chuy
# Processing Record 14 of Set 3 | hasaki
# Processing Record 15 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 3 | saint-augustin
# Processing Record 17 of Set 3 | esperance
# Processing Record 18 of Set 3 | buala
# Processing Record 19 of Set 3 | kulhudhuffushi
# Processing Record 20 of Set 3 | amahai
# Processing Record 21 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 22 of Set 3 | berlevag
# Processing Record 23 of Set 3 | portland
# Processing Record 24 of Set 3 | thompson
# Processing Record 25 of Set 3 | kiunga
# Processing Record 26 of Set 3 | leh
# Processing Record 27 of Set 3 | tabuk
# Processing Record 28 of Set 3 | huarmey
# Processing Record 29 of Set 3 | faanui
# Processing Record 30 of Set 3 | raymond
# Processing Record 31 of Set 3 | san jeronimo
# Processing Record 32 of Set 3 | atuona
# Processing Record 33 of Set 3 | bluff
# Processing Record 34 of Set 3 | georgetown
# Processing Record 35 of Set 3 | indianola
# Processing Record 36 of Set 3 | mar del plata
# Processing Record 37 of Set 3 | safaga
# Processing Record 38 of Set 3 | mehamn
# Processing Record 39 of Set 3 | taoudenni
# Processing Record 40 of Set 3 | hobart
# Processing Record 41 of Set 3 | woodward
# Processing Record 42 of Set 3 | grimari
# City not found. Skipping...
# Processing Record 43 of Set 3 | caravelas
# Processing Record 44 of Set 3 | albany
# Processing Record 45 of Set 3 | rawson
# Processing Record 46 of Set 3 | casablanca
# Processing Record 47 of Set 3 | pangai
# Processing Record 48 of Set 3 | burnie
# Processing Record 49 of Set 3 | klaksvik
# Processing Record 50 of Set 3 | copiapo
# Processing Record 1 of Set 4 | sioux lookout
# Processing Record 2 of Set 4 | westport
# Processing Record 3 of Set 4 | vila franca do campo
# Processing Record 4 of Set 4 | paranaiba
# Processing Record 5 of Set 4 | santa maria
# Processing Record 6 of Set 4 | neuquen
# Processing Record 7 of Set 4 | micheweni
# Processing Record 8 of Set 4 | chaykovskaya
# Processing Record 9 of Set 4 | cherskiy
# Processing Record 10 of Set 4 | kuvshinovo
# Processing Record 11 of Set 4 | bambous virieux
# Processing Record 12 of Set 4 | jiwani
# Processing Record 13 of Set 4 | clyde river
# Processing Record 14 of Set 4 | padang
# Processing Record 15 of Set 4 | cabedelo
# Processing Record 16 of Set 4 | qaanaaq
# Processing Record 17 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 4 | honiara
# Processing Record 19 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 4 | iroquois falls
# Processing Record 21 of Set 4 | pacifica
# Processing Record 22 of Set 4 | tucano
# Processing Record 23 of Set 4 | vao
# Processing Record 24 of Set 4 | saint-joseph
# Processing Record 25 of Set 4 | bethel
# Processing Record 26 of Set 4 | melo
# Processing Record 27 of Set 4 | balotra
# Processing Record 28 of Set 4 | kapaa
# Processing Record 29 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 30 of Set 4 | los llanos de aridane
# Processing Record 31 of Set 4 | fort nelson
# Processing Record 32 of Set 4 | araouane
# Processing Record 33 of Set 4 | rorvik
# Processing Record 34 of Set 4 | rosario
# Processing Record 35 of Set 4 | kaitangata
# Processing Record 36 of Set 4 | castro
# Processing Record 37 of Set 4 | dogbo
# Processing Record 38 of Set 4 | panzhihua
# Processing Record 39 of Set 4 | aksu
# Processing Record 40 of Set 4 | oregon city
# Processing Record 41 of Set 4 | ganzhou
# Processing Record 42 of Set 4 | katangli
# Processing Record 43 of Set 4 | leningradskiy
# Processing Record 44 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 45 of Set 4 | muros
# Processing Record 46 of Set 4 | coahuayana
# Processing Record 47 of Set 4 | robore
# Processing Record 48 of Set 4 | along
# Processing Record 49 of Set 4 | naze
# Processing Record 50 of Set 4 | sao joao da barra
# Processing Record 1 of Set 5 | chokurdakh
# Processing Record 2 of Set 5 | port alfred
# Processing Record 3 of Set 5 | belaya gora
# Processing Record 4 of Set 5 | cayenne
# Processing Record 5 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 6 of Set 5 | farah
# Processing Record 7 of Set 5 | mount gambier
# Processing Record 8 of Set 5 | mabaruma
# Processing Record 9 of Set 5 | dongsheng
# Processing Record 10 of Set 5 | kavieng
# Processing Record 11 of Set 5 | mahebourg
# Processing Record 12 of Set 5 | huesca
# Processing Record 13 of Set 5 | deputatskiy
# Processing Record 14 of Set 5 | nantucket
# Processing Record 15 of Set 5 | lavrentiya
# Processing Record 16 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 17 of Set 5 | zhigalovo
# Processing Record 18 of Set 5 | hokitika
# Processing Record 19 of Set 5 | watsa
# Processing Record 20 of Set 5 | antalaha
# Processing Record 21 of Set 5 | palmer
# Processing Record 22 of Set 5 | ratnagiri
# Processing Record 23 of Set 5 | hervey bay
# Processing Record 24 of Set 5 | alexandria
# Processing Record 25 of Set 5 | airai
# Processing Record 26 of Set 5 | houma
# Processing Record 27 of Set 5 | iqaluit
# Processing Record 28 of Set 5 | atlantis
# Processing Record 29 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 5 | omsukchan
# Processing Record 31 of Set 5 | touros
# Processing Record 32 of Set 5 | gospic
# Processing Record 33 of Set 5 | moundsville
# Processing Record 34 of Set 5 | namatanai
# Processing Record 35 of Set 5 | hambantota
# Processing Record 36 of Set 5 | pangnirtung
# Processing Record 37 of Set 5 | nizhniye vyazovyye
# Processing Record 38 of Set 5 | basudebpur
# Processing Record 39 of Set 5 | port hardy
# Processing Record 40 of Set 5 | gat
# Processing Record 41 of Set 5 | port macquarie
# Processing Record 42 of Set 5 | khani
# Processing Record 43 of Set 5 | naugarzan
# City not found. Skipping...
# Processing Record 44 of Set 5 | reconquista
# Processing Record 45 of Set 5 | asau
# Processing Record 46 of Set 5 | mangrol
# Processing Record 47 of Set 5 | sur
# Processing Record 48 of Set 5 | moose factory
# Processing Record 49 of Set 5 | barrow
# Processing Record 50 of Set 5 | lompoc
# Processing Record 1 of Set 6 | fairview
# Processing Record 2 of Set 6 | matamoros
# Processing Record 3 of Set 6 | barcelos
# Processing Record 4 of Set 6 | isangel
# Processing Record 5 of Set 6 | santa catarina de tepehuanes
# Processing Record 6 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 6 | varlamovo
# Processing Record 8 of Set 6 | ndele
# Processing Record 9 of Set 6 | broome
# Processing Record 10 of Set 6 | xichang
# Processing Record 11 of Set 6 | krasnoselkup
# Processing Record 12 of Set 6 | thano bula khan
# City not found. Skipping...
# Processing Record 13 of Set 6 | morgan city
# Processing Record 14 of Set 6 | itaituba
# Processing Record 15 of Set 6 | ombessa
# Processing Record 16 of Set 6 | pisco
# Processing Record 17 of Set 6 | la reforma
# Processing Record 18 of Set 6 | dikson
# Processing Record 19 of Set 6 | coffs harbour
# Processing Record 20 of Set 6 | andevoranto
# City not found. Skipping...
# Processing Record 21 of Set 6 | saltillo
# Processing Record 22 of Set 6 | te anau
# Processing Record 23 of Set 6 | longyearbyen
# Processing Record 24 of Set 6 | san felipe
# Processing Record 25 of Set 6 | pacific grove
# Processing Record 26 of Set 6 | baruun-urt
# Processing Record 27 of Set 6 | kralendijk
# Processing Record 28 of Set 6 | zhoucheng
# Processing Record 29 of Set 6 | ahipara
# Processing Record 30 of Set 6 | saint george
# Processing Record 31 of Set 6 | lahore
# Processing Record 32 of Set 6 | fairbanks
# Processing Record 33 of Set 6 | inhambane
# Processing Record 34 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 35 of Set 6 | yerofey pavlovich
# Processing Record 36 of Set 6 | beloha
# Processing Record 37 of Set 6 | strehaia
# Processing Record 38 of Set 6 | esfarayen
# Processing Record 39 of Set 6 | stornoway
# Processing Record 40 of Set 6 | smoky lake
# Processing Record 41 of Set 6 | bur gabo
# City not found. Skipping...
# Processing Record 42 of Set 6 | anqing
# Processing Record 43 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 44 of Set 6 | viedma
# Processing Record 45 of Set 6 | guia de isora
# Processing Record 46 of Set 6 | rudbar
# Processing Record 47 of Set 6 | whitianga
# Processing Record 48 of Set 6 | port hedland
# Processing Record 49 of Set 6 | kawalu
# Processing Record 50 of Set 6 | imbituba
# Processing Record 1 of Set 7 | hay river
# Processing Record 2 of Set 7 | taraclia
# Processing Record 3 of Set 7 | nishihara
# Processing Record 4 of Set 7 | san ramon de la nueva oran
# Processing Record 5 of Set 7 | aloleng
# Processing Record 6 of Set 7 | talnakh
# Processing Record 7 of Set 7 | norman wells
# Processing Record 8 of Set 7 | zhuhai
# Processing Record 9 of Set 7 | valdivia
# Processing Record 10 of Set 7 | vestmannaeyjar
# Processing Record 11 of Set 7 | maniitsoq
# Processing Record 12 of Set 7 | bend
# Processing Record 13 of Set 7 | zhezkazgan
# Processing Record 14 of Set 7 | nouakchott
# Processing Record 15 of Set 7 | san cristobal
# Processing Record 16 of Set 7 | kirakira
# Processing Record 17 of Set 7 | cumaribo
# City not found. Skipping...
# Processing Record 18 of Set 7 | tyrma
# Processing Record 19 of Set 7 | kruisfontein
# Processing Record 20 of Set 7 | vysokaya gora
# Processing Record 21 of Set 7 | karratha
# Processing Record 22 of Set 7 | santo antonio
# Processing Record 23 of Set 7 | hobyo
# Processing Record 24 of Set 7 | umm lajj
# Processing Record 25 of Set 7 | gardendale
# Processing Record 26 of Set 7 | tigil
# Processing Record 27 of Set 7 | codrington
# Processing Record 28 of Set 7 | narasannapeta
# Processing Record 29 of Set 7 | aykhal
# Processing Record 30 of Set 7 | puerto cabezas
# Processing Record 31 of Set 7 | jose de freitas
# Processing Record 32 of Set 7 | yarmouth
# Processing Record 33 of Set 7 | ngunguru
# Processing Record 34 of Set 7 | ucluelet
# Processing Record 35 of Set 7 | kharp
# Processing Record 36 of Set 7 | acarau
# Processing Record 37 of Set 7 | alta floresta
# Processing Record 38 of Set 7 | jumla
# Processing Record 39 of Set 7 | athabasca
# Processing Record 40 of Set 7 | vittoria
# Processing Record 41 of Set 7 | adrar
# Processing Record 42 of Set 7 | monrovia
# Processing Record 43 of Set 7 | grand gaube
# Processing Record 44 of Set 7 | souillac
# Processing Record 45 of Set 7 | sampit
# Processing Record 46 of Set 7 | san policarpo
# Processing Record 47 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 48 of Set 7 | hof
# Processing Record 49 of Set 7 | yulara
# Processing Record 50 of Set 7 | fortuna
# Processing Record 1 of Set 8 | tolaga bay
# Processing Record 2 of Set 8 | suntar
# Processing Record 3 of Set 8 | kalianget
# Processing Record 4 of Set 8 | pochutla
# Processing Record 5 of Set 8 | tabou
# Processing Record 6 of Set 8 | zalegoshch
# Processing Record 7 of Set 8 | baykit
# Processing Record 8 of Set 8 | valeni
# Processing Record 9 of Set 8 | lima
# Processing Record 10 of Set 8 | alofi
# Processing Record 11 of Set 8 | robertsport
# Processing Record 12 of Set 8 | great yarmouth
# Processing Record 13 of Set 8 | karauzyak
# City not found. Skipping...
# Processing Record 14 of Set 8 | kargasok
# Processing Record 15 of Set 8 | boa vista
# Processing Record 16 of Set 8 | zhanaozen
# Processing Record 17 of Set 8 | kalabo
# Processing Record 18 of Set 8 | broken hill
# Processing Record 19 of Set 8 | shitanjing
# Processing Record 20 of Set 8 | wahran
# City not found. Skipping...
# Processing Record 21 of Set 8 | qandahar
# City not found. Skipping...
# Processing Record 22 of Set 8 | pitimbu
# Processing Record 23 of Set 8 | curuguaty
# Processing Record 24 of Set 8 | maracaju
# Processing Record 25 of Set 8 | katherine
# Processing Record 26 of Set 8 | longkou
# Processing Record 27 of Set 8 | victoria
# Processing Record 28 of Set 8 | khilok
# Processing Record 29 of Set 8 | aksay
# Processing Record 30 of Set 8 | tubruq
# City not found. Skipping...
# Processing Record 31 of Set 8 | rapina
# Processing Record 32 of Set 8 | lethem
# Processing Record 33 of Set 8 | mawlaik
# Processing Record 34 of Set 8 | bandarbeyla
# Processing Record 35 of Set 8 | denpasar
# Processing Record 36 of Set 8 | severnyy
# Processing Record 37 of Set 8 | yerbogachen
# Processing Record 38 of Set 8 | kieta
# Processing Record 39 of Set 8 | brae
# Processing Record 40 of Set 8 | saint-pierre
# Processing Record 41 of Set 8 | tegh
# Processing Record 42 of Set 8 | yakeshi
# Processing Record 43 of Set 8 | chapais
# Processing Record 44 of Set 8 | ust-maya
# Processing Record 45 of Set 8 | sulangan
# Processing Record 46 of Set 8 | ishigaki
# Processing Record 47 of Set 8 | salym
# Processing Record 48 of Set 8 | yining
# Processing Record 49 of Set 8 | abadan
# Processing Record 50 of Set 8 | axim
# Processing Record 1 of Set 9 | vila
# Processing Record 2 of Set 9 | benavente
# Processing Record 3 of Set 9 | narsaq
# Processing Record 4 of Set 9 | tuensang
# Processing Record 5 of Set 9 | abu samrah
# Processing Record 6 of Set 9 | margate
# Processing Record 7 of Set 9 | urumqi
# Processing Record 8 of Set 9 | kangaatsiaq
# Processing Record 9 of Set 9 | iquitos
# Processing Record 10 of Set 9 | carutapera
# Processing Record 11 of Set 9 | singida
# Processing Record 12 of Set 9 | whitehorse
# Processing Record 13 of Set 9 | roma
# Processing Record 14 of Set 9 | kenora
# Processing Record 15 of Set 9 | talaja
# Processing Record 16 of Set 9 | ballina
# Processing Record 17 of Set 9 | kungurtug
# Processing Record 18 of Set 9 | shakawe
# Processing Record 19 of Set 9 | veraval
# Processing Record 20 of Set 9 | waingapu
# Processing Record 21 of Set 9 | prince rupert
# Processing Record 22 of Set 9 | nome
# Processing Record 23 of Set 9 | uray
# Processing Record 24 of Set 9 | north bend
# Processing Record 25 of Set 9 | bosaso
# Processing Record 26 of Set 9 | kyabe
# Processing Record 27 of Set 9 | victor harbor
# Processing Record 28 of Set 9 | arman
# Processing Record 29 of Set 9 | mount darwin
# Processing Record 30 of Set 9 | great falls
# Processing Record 31 of Set 9 | tamandare
# Processing Record 32 of Set 9 | diego de almagro
# Processing Record 33 of Set 9 | palm coast
# Processing Record 34 of Set 9 | tura
# Processing Record 35 of Set 9 | komsomolskiy
# Processing Record 36 of Set 9 | sitka
# Processing Record 37 of Set 9 | jurmala
# Processing Record 38 of Set 9 | neftegorsk
# Processing Record 39 of Set 9 | riyadh
# Processing Record 40 of Set 9 | san onofre
# Processing Record 41 of Set 9 | skjervoy
# Processing Record 42 of Set 9 | longyan
# Processing Record 43 of Set 9 | adre
# Processing Record 44 of Set 9 | kloulklubed
# Processing Record 45 of Set 9 | jalu
# Processing Record 46 of Set 9 | phoenix
# Processing Record 47 of Set 9 | guayaramerin
# Processing Record 48 of Set 9 | harbour breton
# Processing Record 49 of Set 9 | bud
# Processing Record 50 of Set 9 | stepnogorsk
# Processing Record 1 of Set 10 | alihe
# Processing Record 2 of Set 10 | banda aceh
# Processing Record 3 of Set 10 | gusinoye ozero
# Processing Record 4 of Set 10 | husavik
# Processing Record 5 of Set 10 | malakal
# Processing Record 6 of Set 10 | port antonio
# Processing Record 7 of Set 10 | lorengau
# Processing Record 8 of Set 10 | mus
# Processing Record 9 of Set 10 | zykovo
# Processing Record 10 of Set 10 | kutum
# Processing Record 11 of Set 10 | uwayl
# City not found. Skipping...
# Processing Record 12 of Set 10 | saint-jean-de-maurienne
# Processing Record 13 of Set 10 | brownwood
# Processing Record 14 of Set 10 | saint-georges
# Processing Record 15 of Set 10 | zaraza
# Processing Record 16 of Set 10 | ennis
# Processing Record 17 of Set 10 | ronneby
# Processing Record 18 of Set 10 | henderson
# Processing Record 19 of Set 10 | nabire
# Processing Record 20 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 21 of Set 10 | verkhnevilyuysk
# Processing Record 22 of Set 10 | erenhot
# Processing Record 23 of Set 10 | cilegon
# Processing Record 24 of Set 10 | limenaria
# Processing Record 25 of Set 10 | lobito
# Processing Record 26 of Set 10 | green river
# Processing Record 27 of Set 10 | elizabethtown
# Processing Record 28 of Set 10 | ancud
# Processing Record 29 of Set 10 | haines junction
# Processing Record 30 of Set 10 | mitu
# Processing Record 31 of Set 10 | poum
# Processing Record 32 of Set 10 | areosa
# Processing Record 33 of Set 10 | el alto
# Processing Record 34 of Set 10 | estacion coahuila
# Processing Record 35 of Set 10 | sobolevo
# Processing Record 36 of Set 10 | hofn
# Processing Record 37 of Set 10 | abalak
# Processing Record 38 of Set 10 | harper
# Processing Record 39 of Set 10 | port blair
# Processing Record 40 of Set 10 | yinchuan
# Processing Record 41 of Set 10 | oktyabrskoye
# Processing Record 42 of Set 10 | xining
# Processing Record 43 of Set 10 | kurchum
# Processing Record 44 of Set 10 | marrakesh
# Processing Record 45 of Set 10 | conakry
# Processing Record 46 of Set 10 | bell ville
# Processing Record 47 of Set 10 | colesberg
# Processing Record 48 of Set 10 | carroll
# Processing Record 49 of Set 10 | armidale
# Processing Record 50 of Set 10 | kariba
# Processing Record 1 of Set 11 | chivay
# Processing Record 2 of Set 11 | kargopol
# Processing Record 3 of Set 11 | bonthe
# Processing Record 4 of Set 11 | quatre cocos
# Processing Record 5 of Set 11 | buchloe
# Processing Record 6 of Set 11 | batagay-alyta
# Processing Record 7 of Set 11 | kleck
# City not found. Skipping...
# Processing Record 8 of Set 11 | kurumkan
# Processing Record 9 of Set 11 | aswan
# Processing Record 10 of Set 11 | rio gallegos
# Processing Record 11 of Set 11 | puerto escondido
# Processing Record 12 of Set 11 | pestovo
# Processing Record 13 of Set 11 | vary
# Processing Record 14 of Set 11 | kodiak
# Processing Record 15 of Set 11 | anadyr
# Processing Record 16 of Set 11 | nakamura
# Processing Record 17 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 18 of Set 11 | camocim
# Processing Record 19 of Set 11 | ottersberg
# Processing Record 20 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 21 of Set 11 | umm kaddadah
# Processing Record 22 of Set 11 | mesagne
# Processing Record 23 of Set 11 | east wenatchee bench
# Processing Record 24 of Set 11 | bonanza
# Processing Record 25 of Set 11 | ketchikan
# Processing Record 26 of Set 11 | toba tek singh
# Processing Record 27 of Set 11 | lower burrell
# Processing Record 28 of Set 11 | les cayes
# Processing Record 29 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 30 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 31 of Set 11 | itacare
# Processing Record 32 of Set 11 | makakilo city
# Processing Record 33 of Set 11 | englewood
# Processing Record 34 of Set 11 | terrace
# Processing Record 35 of Set 11 | dhule
# Processing Record 36 of Set 11 | vanavara
# Processing Record 37 of Set 11 | san quintin
# Processing Record 38 of Set 11 | mandera
# Processing Record 39 of Set 11 | kormilovka
# Processing Record 40 of Set 11 | eminabad
# Processing Record 41 of Set 11 | porto novo
# Processing Record 42 of Set 11 | aksarka
# Processing Record 43 of Set 11 | ostrovnoy
# Processing Record 44 of Set 11 | scottsbluff
# Processing Record 45 of Set 11 | kasongo-lunda
# Processing Record 46 of Set 11 | balkanabat
# Processing Record 47 of Set 11 | mogadishu
# Processing Record 48 of Set 11 | sinjai
# Processing Record 49 of Set 11 | zyryanka
# Processing Record 50 of Set 11 | joura
# Processing Record 1 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 2 of Set 12 | kitimat
# Processing Record 3 of Set 12 | merauke
# Processing Record 4 of Set 12 | kannangad
# Processing Record 5 of Set 12 | hirara
# Processing Record 6 of Set 12 | ixtapa
# Processing Record 7 of Set 12 | santiago del estero
# Processing Record 8 of Set 12 | qaqortoq
# Processing Record 9 of Set 12 | sindor
# Processing Record 10 of Set 12 | abu kamal
# Processing Record 11 of Set 12 | tazovskiy
# Processing Record 12 of Set 12 | riviere-au-renard
# Processing Record 13 of Set 12 | aranda de duero
# Processing Record 14 of Set 12 | iracoubo
# Processing Record 15 of Set 12 | mitsamiouli
# Processing Record 16 of Set 12 | touho
# Processing Record 17 of Set 12 | puerto madryn
# Processing Record 18 of Set 12 | bairiki
# Processing Record 19 of Set 12 | halifax
# Processing Record 20 of Set 12 | mashhad
# Processing Record 21 of Set 12 | puerto ayacucho
# Processing Record 22 of Set 12 | canning
# Processing Record 23 of Set 12 | chipinge
# Processing Record 24 of Set 12 | henties bay
# Processing Record 25 of Set 12 | hanyang
# Processing Record 26 of Set 12 | teahupoo
# Processing Record 27 of Set 12 | nyrob
# Processing Record 28 of Set 12 | satipo
# Processing Record 29 of Set 12 | byron bay
# Processing Record 30 of Set 12 | abu dhabi
# Processing Record 31 of Set 12 | sandwick
# Processing Record 32 of Set 12 | bilibino
# Processing Record 33 of Set 12 | milingimbi
# City not found. Skipping...
# Processing Record 34 of Set 12 | oloron-sainte-marie
# Processing Record 35 of Set 12 | san luis
# Processing Record 36 of Set 12 | mersing
# Processing Record 37 of Set 12 | neftekamsk
# Processing Record 38 of Set 12 | smederevska palanka
# Processing Record 39 of Set 12 | fanai
# Processing Record 40 of Set 12 | progreso
# Processing Record 41 of Set 12 | samarai
# Processing Record 42 of Set 12 | the valley
# Processing Record 43 of Set 12 | marawi
# Processing Record 44 of Set 12 | karpenision
# City not found. Skipping...
# Processing Record 45 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 46 of Set 12 | kitami
# Processing Record 47 of Set 12 | bongandanga
# Processing Record 48 of Set 12 | nekhayevskiy
# Processing Record 49 of Set 12 | yar-sale
# Processing Record 50 of Set 12 | balikpapan
# Processing Record 1 of Set 13 | sal
# Processing Record 2 of Set 13 | aransas pass
# Processing Record 3 of Set 13 | namibe
# Processing Record 4 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 5 of Set 13 | lianzhou
# Processing Record 6 of Set 13 | tautira
# Processing Record 7 of Set 13 | sovetskiy
# Processing Record 8 of Set 13 | mukhen
# Processing Record 9 of Set 13 | coulihaut
# City not found. Skipping...
# Processing Record 10 of Set 13 | porto seguro
# Processing Record 11 of Set 13 | changji
# Processing Record 12 of Set 13 | pringsewu
# Processing Record 13 of Set 13 | tilichiki
# Processing Record 14 of Set 13 | sangin
# Processing Record 15 of Set 13 | ibipeba
# Processing Record 16 of Set 13 | mount pleasant
# Processing Record 17 of Set 13 | emba
# Processing Record 18 of Set 13 | bowen
# Processing Record 19 of Set 13 | basoko
# Processing Record 20 of Set 13 | santa lucia
# Processing Record 21 of Set 13 | darnah
# Processing Record 22 of Set 13 | mareeba
# Processing Record 23 of Set 13 | isla mujeres
# Processing Record 24 of Set 13 | vostok
# Processing Record 25 of Set 13 | yenagoa
# Processing Record 26 of Set 13 | bonfim
# Processing Record 27 of Set 13 | carupano
# Processing Record 28 of Set 13 | borogontsy
# Processing Record 29 of Set 13 | abha
# Processing Record 30 of Set 13 | imeni poliny osipenko
# Processing Record 31 of Set 13 | kautokeino
# Processing Record 32 of Set 13 | pithiviers
# Processing Record 33 of Set 13 | sosnovo-ozerskoye
# Processing Record 34 of Set 13 | mercedes
# Processing Record 35 of Set 13 | sao gotardo
# Processing Record 36 of Set 13 | orbetello
# Processing Record 37 of Set 13 | eyl
# Processing Record 38 of Set 13 | ulladulla
# Processing Record 39 of Set 13 | haapiti
# Processing Record 40 of Set 13 | uhlove
# Processing Record 41 of Set 13 | altamira
# Processing Record 42 of Set 13 | mecca
# Processing Record 43 of Set 13 | mpika
# Processing Record 44 of Set 13 | korampallam
# Processing Record 45 of Set 13 | kropotkin
# Processing Record 46 of Set 13 | kahului
# Processing Record 47 of Set 13 | ewa beach
# Processing Record 48 of Set 13 | dedovichi
# Processing Record 49 of Set 13 | ambam
# Processing Record 50 of Set 13 | kashkhatau
# Processing Record 1 of Set 14 | talca
# Processing Record 2 of Set 14 | villamontes
# Processing Record 3 of Set 14 | mlonggo
# Processing Record 4 of Set 14 | cockburn town
# Processing Record 5 of Set 14 | gravdal
# Processing Record 6 of Set 14 | wahpeton
# Processing Record 7 of Set 14 | upata
# Processing Record 8 of Set 14 | bay roberts
# Processing Record 9 of Set 14 | gaoua
# Processing Record 10 of Set 14 | sambava
# Processing Record 11 of Set 14 | aleksandrov gay
# Processing Record 12 of Set 14 | kostelec na hane
# Processing Record 13 of Set 14 | saldanha
# Processing Record 14 of Set 14 | evensk
# Processing Record 15 of Set 14 | shingu
# Processing Record 16 of Set 14 | renqiu
# Processing Record 17 of Set 14 | durazno
# Processing Record 18 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 19 of Set 14 | hunza
# City not found. Skipping...
# Processing Record 20 of Set 14 | egvekinot
# Processing Record 21 of Set 14 | aktas
# Processing Record 22 of Set 14 | coquimbo
# Processing Record 23 of Set 14 | uruzgan
# Processing Record 24 of Set 14 | flinders
# Processing Record 25 of Set 14 | nemuro
# Processing Record 26 of Set 14 | muyezerskiy
# Processing Record 27 of Set 14 | eureka
# Processing Record 28 of Set 14 | pomabamba
# Processing Record 29 of Set 14 | kaeo
# Processing Record 30 of Set 14 | high level
# Processing Record 31 of Set 14 | puerto colombia
# Processing Record 32 of Set 14 | ponta delgada
# Processing Record 33 of Set 14 | sumenep
# Processing Record 34 of Set 14 | belmonte
# Processing Record 35 of Set 14 | varaklani
# City not found. Skipping...
# Processing Record 36 of Set 14 | tahta
# Processing Record 37 of Set 14 | harnosand
# Processing Record 38 of Set 14 | khowst
# Processing Record 39 of Set 14 | kutahya
# Processing Record 40 of Set 14 | severo-yeniseyskiy
# Processing Record 41 of Set 14 | salvador
# Processing Record 42 of Set 14 | lishui
# Processing Record 43 of Set 14 | juneau
# Processing Record 44 of Set 14 | ulaanbaatar
# Processing Record 45 of Set 14 | ileza
# Processing Record 46 of Set 14 | tukrah
# Processing Record 47 of Set 14 | beira
# Processing Record 48 of Set 14 | ariquemes
# Processing Record 49 of Set 14 | aden
# Processing Record 50 of Set 14 | punta alta
# Processing Record 1 of Set 15 | port shepstone
# Processing Record 2 of Set 15 | bubaque
# Processing Record 3 of Set 15 | karakol
# Processing Record 4 of Set 15 | sokur
# Processing Record 5 of Set 15 | tabulbah
# City not found. Skipping...
# Processing Record 6 of Set 15 | malino
# Processing Record 7 of Set 15 | wilmington
# Processing Record 8 of Set 15 | nouadhibou
# Processing Record 9 of Set 15 | santa isabel do rio negro
# Processing Record 10 of Set 15 | kamenka
# Processing Record 11 of Set 15 | abnub
# Processing Record 12 of Set 15 | hoquiam
# Processing Record 13 of Set 15 | nyurba
# Processing Record 14 of Set 15 | kavaratti
# Processing Record 15 of Set 15 | moerai
# Processing Record 16 of Set 15 | mayo
# Processing Record 17 of Set 15 | phalombe
# Processing Record 18 of Set 15 | ciudad bolivar
# Processing Record 19 of Set 15 | monsummano terme
# Processing Record 20 of Set 15 | korla
# Processing Record 21 of Set 15 | tshikapa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0         Upernavik      GL  72.7868  -56.1549      1.63        98
# 1          Buraydah      SA  26.3260   43.9750     68.13        25
# 2   Arraial Do Cabo      BR -22.9661  -42.0278     77.67        88
# 3           Salalah      OM  17.0151   54.0924     71.83        64
# 4           Itarema      BR  -2.9248  -39.9167     84.04        65
# 5  Nogent-Le-Rotrou      FR  48.3333    1.0000     42.80        85
# 6    Ribeira Grande      PT  38.5167  -28.7000     61.20        77
# 7       Tuktoyaktuk      CA  69.4541 -133.0374    -24.63        99
# 8            Nicoya      CR  10.1483  -85.4520     93.31        37
# 9        Butaritari      KI   3.0707  172.7902     82.53        73
#
#    Cloudiness  Wind Speed Current Description
# 0         100       10.27     overcast clouds
# 1          36       14.16    scattered clouds
# 2          94       13.24     overcast clouds
# 3           1        0.78           clear sky
# 4         100       15.23       moderate rain
# 5          73        7.76       broken clouds
# 6          40       17.27    scattered clouds
# 7          41       10.33    scattered clouds
# 8           7       13.02           clear sky
# 9           6       18.14           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
